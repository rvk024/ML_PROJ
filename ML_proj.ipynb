# %% [markdown]
# #### Importing the Libraries
#
# In the cell below, the required Libraries and packages

# %%
import pandas as pd
import nltk
from sklearn.model_selection import train_test_split
import re
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.probability import FreqDist
from nltk.probability import ConditionalFreqDist

# %% [markdown]
# #### Tokenizing the text
#
# Here in the below function text is tokenized the stop words, noun and verbs along with the filteration of the words starting with special characters.

# %%
   '''This is the backup
   def tokenize(data):
    lst = data['review']
    pattern = re.compile('^[^A-Za-z0-9]')
    s2w = word_tokenize(lst)
    stop_words = set(stopwords.words("english"))
    return  [word.casefold()  for word in s2w if word.casefold() not in stop_words and len(re.findall(pattern, word.casefold())) == 0]'''

def tokenize(data):
    lst = data['review']
    pattern = re.compile('^[^A-Za-z0-9]') #Creating regex string
    s2w = word_tokenize(lst)
    stop_words = set(stopwords.words("english"))
    parts_of_speech = nltk.pos_tag(s2w) #pos_tag gives the parts of speech of a sentence
    filter_pos = ['NN', 'VB'] # Here NN stands for noun and VB stans for Verb
    words_exclude = [pos[0].casefold() for pos in parts_of_speech if pos[1] not in filter_pos and  pos[0].casefold() not in stop_words and len(re.findall(pattern,pos[0].casefold())) == 0] # Creating a list of words
    return words_exclude

# %% [markdown]
# #### Frequency Distrubution
# in the blow function we are calculating the frequency distribution and the conditional frequency distribution of the words

# %%
def freq_dist(data):
    review_freq_dist = FreqDist()
    review_cond_freq_dist = ConditionalFreqDist()
    for i in range (0, len(data)):
        for word in data['review_token'][i]:
            review_freq_dist[word] +=1
           # print(data['sentiment'][i])
            review_cond_freq_dist[data['sentiment'][i]][word] += 1
    return [review_freq_dist, review_cond_freq_dist]

# %% [markdown]
# Reading the raw data from the dataset

# %%
raw_data = pd.read_csv(filepath_or_buffer = "Data\IMDB - Cleansed data from Kaggle\IMDB Dataset.csv", header = 'infer')

# %% [markdown]
# Removing the line break html tags

# %%
raw_data_tag_rem = raw_data.replace(regex=['<br /><br />'], value = ' ')

# %% [markdown]
# Separating positive sentiment and the negative sentiment data to divide data into test and train

# %%
positive = raw_data_tag_rem[raw_data_tag_rem['sentiment'] == 'positive']
negative = raw_data_tag_rem[raw_data_tag_rem['sentiment'] == 'negative']

# %%
x_pos_train, x_pos_test, y_pos_train, y_pos_test = train_test_split(positive['review'], positive['sentiment'], test_size=1/4, random_state=42) 
x_neg_train, x_neg_test, y_neg_train, y_neg_test = train_test_split(negative['review'], negative['sentiment'], test_size=1/4, random_state=42)

# %% [markdown]
# appending the positive and the negative training data set and applying tokenize function for the field review_token

# %%
x_train = x_pos_train._append(x_neg_train)
y_train = y_pos_train._append(y_neg_train)
training_data = pd.concat([x_train, y_train], axis=1)
training_data['review_token'] = training_data.apply(tokenize, axis=1)
training_data = training_data.set_index(pd.Index([i for i in range (0, len(training_data))]))

# %%
training_data
# Out:
#                                                   review sentiment  \
# 0      I was not expecting the powerful filmmaking ex...  positive
# 1      Somewhere in the dark recesses of my brain cel...  positive
# 2      Surprisingly good "Mean Streets"-type crime dr...  positive
# 3      It plays like your usual teenage-audience T&A ...  positive
# 4      Fans of Gerry Anderson's productions will reco...  positive
# ...                                                  ...       ...
# 37495  The operative rule in the making of this film ...  negative
# 37496  The plot outline of this movie is similar to t...  negative
# 37497  Obviously, the comments above that fawn over t...  negative
# 37498  This movie had the potential to be far more th...  negative
# 37499  T. Rama Rao made some extremely beautiful film...  negative
#
#                                             review_token
# 0      [expecting, powerful, filmmaking, girlfight, i...
# 1      [somewhere, dark, recesses, cells, plays, ca, ...
# 2      [surprisingly, good, mean, streets, foreshadow...
# 3      [plays, like, usual, incredibly, bleak, made, ...
# 4      [fans, gerry, anderson, productions, several, ...
# ...                                                  ...
# 37495  [operative, seems, never, 1, 10, minute, set, ...
# 37496  [similar, original, someone, gets, kidnapped, ...
# 37497  [obviously, comments, made, n't, ever, seeing,...
# 37498  [potential, far, fails, brings, nauseous, righ...
# 37499  [t., rama, rao, made, extremely, beautiful, fi...
#
# [37500 rows x 3 columns]

# %% [markdown]
# Creating the frequency distribution

# %%
a = freq_dist(training_data)

# %% [markdown]
# obtaining top 10000 most common positive negative and all common words

# %%
negative_most_common_words = a[1]['negative'].most_common(10000)
positive_most_common_words = a[1]['positive'].most_common(10000)
all_most_common_words = a[0].most_common(10000)

# %%
all_most_common_words
# Out:
# [("n't", 49886),
#  ('one', 34645),
#  ('like', 27056),
#  ('good', 21817),
#  ('would', 19789),
#  ('even', 18517),
#  ('really', 17404),
#  ('much', 14377),
#  ('well', 14355),
#  ('could', 13858),
#  ('people', 13552),
#  ('bad', 13499),
#  ('great', 13458),
#  ('also', 13275),
#  ('first', 12881),
#  ('made', 11680),
#  ('movies', 11348),
#  ('characters', 10630),
#  ('seen', 10065),
#  ('many', 10053),
#  ('films', 10004),
#  ('two', 9835),
#  ('never', 9766),
#  ('little', 9291),
#  ('best', 9170),
#  ('ever', 8871),
#  ('better', 8444),
#  ('still', 8071),
#  ('scenes', 7757),
#  ('real', 6730),
#  ('actors', 6601),
#  ('think', 6587),
#  ('watching', 6507),
#  ('though', 6461),
#  ('years', 6439),
#  ('another', 6399),
#  ('back', 6383),
#  ('actually', 6351),
#  ('makes', 6200),
#  ('new', 6032),
#  ('going', 5996),
#  ('funny', 5962),
#  ('every', 5910),
#  ('old', 5824),
#  ('us', 5505),
#  ('things', 5465),
#  ('seems', 5390),
#  ('got', 5373),
#  ('quite', 5279),
#  ('around', 5276),
#  ('ca', 5258),
#  ('pretty', 5202),
#  ('young', 5171),
#  ('however', 5155),
#  ('enough', 5035),
#  ('big', 5016),
#  ('may', 4940),
#  ('without', 4789),
#  ('long', 4783),
#  ('times', 4766),
#  ('must', 4719),
#  ('always', 4716),
#  ('almost', 4695),
#  ('gets', 4684),
#  ('original', 4630),
#  ('saw', 4602),
#  ('least', 4576),
#  ('thought', 4542),
#  ('know', 4477),
#  ('done', 4466),
#  ('interesting', 4418),
#  ('might', 4387),
#  ('minutes', 4379),
#  ('last', 4301),
#  ('far', 4282),
#  ('since', 4277),
#  ('probably', 4179),
#  ('whole', 4124),
#  ('away', 4085),
#  ('yet', 4044),
#  ('right', 3968),
#  ('worst', 3926),
#  ('played', 3878),
#  ('rather', 3829),
#  ('found', 3799),
#  ('especially', 3783),
#  ('sure', 3762),
#  ('although', 3746),
#  ('acting', 3742),
#  ('trying', 3683),
#  ('comes', 3593),
#  ('goes', 3581),
#  ('ending', 3575),
#  ('different', 3504),
#  ('hard', 3498),
#  ('looking', 3484),
#  ('see', 3483),
#  ('dvd', 3478),
#  ('shows', 3464),
#  ('maybe', 3395),
#  ('want', 3391),
#  ('main', 3388),
#  ('watched', 3362),
#  ('looks', 3355),
#  ('three', 3351),
#  ('2', 3327),
#  ('making', 3303),
#  ('get', 3301),
#  ('effects', 3295),
#  ('together', 3281),
#  ('instead', 3273),
#  ('plays', 3233),
#  ('worth', 3222),
#  ('10', 3222),
#  ('true', 3210),
#  ('said', 3187),
#  ('takes', 3176),
#  ('later', 3125),
#  ('john', 3117),
#  ('seeing', 3107),
#  ('love', 3084),
#  ('american', 3080),
#  ('special', 3061),
#  ('else', 2987),
#  ('excellent', 2953),
#  ('left', 2953),
#  ('beautiful', 2905),
#  ('simply', 2904),
#  ('black', 2881),
#  ('completely', 2881),
#  ('poor', 2862),
#  ('nice', 2831),
#  ('used', 2817),
#  ('high', 2808),
#  ('along', 2795),
#  ('short', 2746),
#  ('kids', 2700),
#  ('friends', 2681),
#  ('men', 2675),
#  ('hollywood', 2667),
#  ('either', 2658),
#  ('wrong', 2651),
#  ('performances', 2646),
#  ('given', 2644),
#  ('women', 2629),
#  ('less', 2594),
#  ('next', 2593),
#  ('dead', 2569),
#  ('stupid', 2566),
#  ('second', 2539),
#  ('full', 2495),
#  ('came', 2483),
#  ('moments', 2470),
#  ('getting', 2446),
#  ('terrible', 2435),
#  ('perhaps', 2429),
#  ('awful', 2406),
#  ('classic', 2395),
#  ('others', 2366),
#  ('wonderful', 2362),
#  ('boring', 2337),
#  ('children', 2326),
#  ('often', 2323),
#  ('definitely', 2320),
#  ('truly', 2286),
#  ('gives', 2284),
#  ('finally', 2280),
#  ('certainly', 2277),
#  ('small', 2274),
#  ('lines', 2259),
#  ('absolutely', 2253),
#  ('early', 2227),
#  ('went', 2227),
#  ('human', 2208),
#  ('stars', 2196),
#  ('come', 2190),
#  ('liked', 2190),
#  ('written', 2168),
#  ('felt', 2158),
#  ('make', 2156),
#  ('perfect', 2149),
#  ('several', 2131),
#  ('entire', 2130),
#  ('3', 2128),
#  ('loved', 2122),
#  ('lost', 2118),
#  ('supposed', 2110),
#  ('playing', 2108),
#  ('oh', 2102),
#  ('guys', 2091),
#  ('yes', 2086),
#  ('based', 2077),
#  ('wanted', 2065),
#  ('totally', 2064),
#  ('entertaining', 2061),
#  ('worse', 2034),
#  ('already', 2024),
#  ('final', 2024),
#  ('lives', 2010),
#  ('despite', 2007),
#  ('seemed', 2007),
#  ('put', 1997),
#  ('fans', 1989),
#  ('go', 1988),
#  ('becomes', 1974),
#  ('able', 1973),
#  ('throughout', 1972),
#  ('unfortunately', 1968),
#  ('set', 1960),
#  ('overall', 1945),
#  ('called', 1937),
#  ('white', 1914),
#  ('days', 1904),
#  ('low', 1900),
#  ('wants', 1885),
#  ('1', 1885),
#  ('michael', 1883),
#  ('horrible', 1871),
#  ('gave', 1842),
#  ('tries', 1836),
#  ('wo', 1821),
#  ('mean', 1808),
#  ('works', 1807),
#  ('amazing', 1806),
#  ('parts', 1794),
#  ('turns', 1784),
#  ('fine', 1784),
#  ('enjoyed', 1783),
#  ('girls', 1774),
#  ('seem', 1773),
#  ('eyes', 1771),
#  ('say', 1743),
#  ('behind', 1738),
#  ('sometimes', 1737),
#  ('obviously', 1726),
#  ('killed', 1726),
#  ('directed', 1704),
#  ('took', 1702),
#  ('starts', 1698),
#  ('soon', 1682),
#  ('highly', 1680),
#  ('says', 1680),
#  ('except', 1657),
#  ('late', 1652),
#  ('find', 1639),
#  ('happens', 1638),
#  ('read', 1613),
#  ('watch', 1606),
#  ('extremely', 1603),
#  ('evil', 1600),
#  ('brilliant', 1600),
#  ('stories', 1597),
#  ('favorite', 1588),
#  ('anyway', 1587),
#  ('hilarious', 1577),
#  ('including', 1569),
#  ('involved', 1569),
#  ('decent', 1566),
#  ('top', 1564),
#  ('roles', 1555),
#  ('coming', 1551),
#  ('strong', 1550),
#  ('obvious', 1547),
#  ('particularly', 1547),
#  ('looked', 1543),
#  ('shown', 1542),
#  ('told', 1530),
#  ('mr.', 1527),
#  ('shot', 1527),
#  ('feel', 1526),
#  ('happened', 1526),
#  ('david', 1525),
#  ('look', 1522),
#  ('released', 1508),
#  ('serious', 1505),
#  ('james', 1503),
#  ('robert', 1503),
#  ('possible', 1493),
#  ('taken', 1487),
#  ('known', 1480),
#  ('huge', 1468),
#  ('hours', 1465),
#  ('seriously', 1460),
#  ('exactly', 1457),
#  ('ago', 1452),
#  ('usually', 1448),
#  ('whose', 1443),
#  ('saying', 1440),
#  ('english', 1436),
#  ('started', 1435),
#  ('dark', 1434),
#  ('jokes', 1431),
#  ('alone', 1425),
#  ('ones', 1425),
#  ('across', 1424),
#  ('heard', 1413),
#  ('simple', 1412),
#  ('ridiculous', 1412),
#  ('ok', 1411),
#  ('believe', 1407),
#  ('complete', 1406),
#  ('4', 1404),
#  ('close', 1403),
#  ('ends', 1400),
#  ('major', 1393),
#  ('shots', 1393),
#  ('thinking', 1388),
#  ('5', 1387),
#  ('important', 1384),
#  ('guess', 1384),
#  ('usual', 1376),
#  ('words', 1362),
#  ('knows', 1361),
#  ('taking', 1359),
#  ('scary', 1358),
#  ('turned', 1353),
#  ('apparently', 1353),
#  ('problems', 1351),
#  ('finds', 1350),
#  ('mostly', 1348),
#  ('silly', 1347),
#  ('somewhat', 1342),
#  ('sad', 1342),
#  ('beyond', 1336),
#  ('disappointed', 1334),
#  ('due', 1331),
#  ('talking', 1330),
#  ('local', 1327),
#  ('annoying', 1326),
#  ('four', 1323),
#  ('episodes', 1317),
#  ('basically', 1314),
#  ('clearly', 1312),
#  ('happy', 1301),
#  ('hope', 1297),
#  ('god', 1297),
#  ('knew', 1296),
#  ('events', 1296),
#  ('give', 1294),
#  ('single', 1286),
#  ('upon', 1280),
#  ('songs', 1280),
#  ('whether', 1264),
#  ('slow', 1263),
#  ('need', 1263),
#  ('strange', 1262),
#  ('jack', 1260),
#  ('british', 1259),
#  ('tells', 1259),
#  ('george', 1248),
#  ('giving', 1246),
#  ('cool', 1243),
#  ('predictable', 1233),
#  ('cheap', 1231),
#  ('similar', 1230),
#  ('musical', 1230),
#  ('appears', 1228),
#  ('running', 1228),
#  ('french', 1228),
#  ('needs', 1224),
#  ('enjoyable', 1223),
#  ('within', 1218),
#  ('falls', 1218),
#  ('easily', 1209),
#  ('modern', 1206),
#  ('certain', 1204),
#  ('lots', 1198),
#  ('sets', 1198),
#  ('filmed', 1197),
#  ('five', 1195),
#  ('etc', 1195),
#  ('among', 1191),
#  ('ways', 1190),
#  ('surprised', 1188),
#  ('tried', 1177),
#  ('comments', 1172),
#  ('live', 1169),
#  ('easy', 1168),
#  ('richard', 1158),
#  ('greatest', 1156),
#  ('viewers', 1153),
#  ('romantic', 1153),
#  ('clear', 1150),
#  ('peter', 1149),
#  ('parents', 1144),
#  ('named', 1140),
#  ('comic', 1137),
#  ('nearly', 1136),
#  ('working', 1135),
#  ('actual', 1134),
#  ('fantastic', 1128),
#  ('using', 1128),
#  ('typical', 1124),
#  ('near', 1121),
#  ('famous', 1118),
#  ('elements', 1112),
#  ('feels', 1109),
#  ('moving', 1107),
#  ('gone', 1100),
#  ('paul', 1100),
#  ('wish', 1095),
#  ('showing', 1092),
#  ('points', 1092),
#  ('realistic', 1087),
#  ('begins', 1082),
#  ('half', 1080),
#  ('kept', 1080),
#  ('past', 1079),
#  ('brought', 1079),
#  ('recommend', 1078),
#  ('believable', 1072),
#  ('supporting', 1072),
#  ('king', 1071),
#  ('leads', 1070),
#  ('america', 1070),
#  ('york', 1065),
#  ('general', 1056),
#  ('indeed', 1051),
#  ('sequences', 1048),
#  ('female', 1039),
#  ('tom', 1037),
#  ('eventually', 1037),
#  ('weak', 1034),
#  ('expected', 1033),
#  ('particular', 1032),
#  ('means', 1027),
#  ('decided', 1026),
#  ('remember', 1015),
#  ('became', 1012),
#  ('become', 1012),
#  ('okay', 1011),
#  ('lee', 1010),
#  ('emotional', 1004),
#  ('interested', 1004),
#  ('possibly', 1004),
#  ('poorly', 1002),
#  ('unless', 997),
#  ('reviews', 997),
#  ('straight', 994),
#  ('boys', 991),
#  ('sexual', 990),
#  ('red', 987),
#  ('forced', 985),
#  ('difficult', 982),
#  ('deep', 980),
#  ('leaves', 979),
#  ('war', 977),
#  ('sounds', 977),
#  ('needed', 971),
#  ('meets', 970),
#  ('credits', 970),
#  ('features', 968),
#  ('hands', 965),
#  ('perfectly', 964),
#  ('personal', 961),
#  ('fun', 961),
#  ('man', 959),
#  ('memorable', 958),
#  ('third', 957),
#  ('earlier', 954),
#  ('imdb', 952),
#  ('towards', 951),
#  ('previous', 950),
#  ('show', 946),
#  ('keeps', 945),
#  ('hot', 945),
#  ('movie', 939),
#  ('quickly', 938),
#  ('japanese', 938),
#  ('worked', 933),
#  ('incredibly', 931),
#  ('various', 928),
#  ('powerful', 921),
#  ('badly', 919),
#  ('directors', 918),
#  ('dull', 914),
#  ('fast', 913),
#  ('reasons', 912),
#  ('writers', 910),
#  ('20', 905),
#  ('brings', 904),
#  ('acted', 904),
#  ('joe', 898),
#  ('william', 894),
#  ('disney', 893),
#  ('de', 893),
#  ('attempts', 892),
#  ('free', 890),
#  ('fairly', 886),
#  ('plus', 884),
#  ('deserves', 881),
#  ('total', 881),
#  ('living', 879),
#  ('killing', 878),
#  ('manages', 876),
#  ('leading', 874),
#  ('otherwise', 871),
#  ('rich', 871),
#  ('fails', 871),
#  ('older', 870),
#  ('unique', 868),
#  ('wasted', 868),
#  ('laugh', 866),
#  ('dramatic', 865),
#  ('lead', 864),
#  ('laughs', 863),
#  ('dr.', 860),
#  ('recently', 859),
#  ('80', 858),
#  ('hardly', 854),
#  ('filmmakers', 853),
#  ('western', 849),
#  ('following', 848),
#  ('ended', 847),
#  ('unlike', 845),
#  ('missing', 843),
#  ('whatever', 843),
#  ('spent', 841),
#  ('sorry', 841),
#  ('portrayed', 837),
#  ('ideas', 836),
#  ('take', 835),
#  ('apart', 835),
#  ('members', 831),
#  ('large', 829),
#  ('world', 829),
#  ('spoilers', 829),
#  ('expecting', 827),
#  ('created', 825),
#  ('talented', 823),
#  ('ten', 823),
#  ('married', 820),
#  ('dumb', 818),
#  ('star', 818),
#  ('writing', 817),
#  ('outside', 815),
#  ('political', 812),
#  ('bill', 812),
#  ('german', 810),
#  ('italian', 808),
#  ('considering', 808),
#  ('reading', 805),
#  ('caught', 805),
#  ('incredible', 804),
#  ('popular', 803),
#  ('weird', 803),
#  ('mentioned', 799),
#  ('produced', 798),
#  ('missed', 798),
#  ('familiar', 798),
#  ('died', 796),
#  ('sadly', 794),
#  ('somehow', 793),
#  ('inside', 792),
#  ('decides', 791),
#  ('waiting', 791),
#  ('visual', 788),
#  ('slightly', 787),
#  ('house', 785),
#  ('sees', 785),
#  ('suddenly', 780),
#  ('bored', 780),
#  ('compared', 778),
#  ('scott', 778),
#  ('wrote', 776),
#  ('images', 775),
#  ('entirely', 775),
#  ('ultimately', 774),
#  ('uses', 769),
#  ('crazy', 769),
#  ('jane', 767),
#  ('moves', 764),
#  ('common', 763),
#  ('laughing', 763),
#  ('brothers', 761),
#  ('odd', 759),
#  ('meant', 756),
#  ('follows', 756),
#  ('former', 752),
#  ('neither', 750),
#  ('telling', 750),
#  ('successful', 750),
#  ('social', 748),
#  ('biggest', 747),
#  ('open', 745),
#  ('pathetic', 745),
#  ('oscar', 744),
#  ('forward', 743),
#  ('flat', 741),
#  ('recommended', 739),
#  ('sci-fi', 738),
#  ('average', 737),
#  ('basic', 736),
#  ('film', 736),
#  ('producers', 734),
#  ('situations', 727),
#  ('changed', 725),
#  ('alive', 724),
#  ('recent', 724),
#  ('positive', 723),
#  ('30', 722),
#  ('kills', 720),
#  ('impossible', 720),
#  ('leaving', 719),
#  ('questions', 719),
#  ('director', 717),
#  ('night', 717),
#  ('longer', 716),
#  ('effective', 716),
#  ('solid', 716),
#  ('city', 711),
#  ('likes', 711),
#  ('immediately', 708),
#  ('somewhere', 707),
#  ('filled', 707),
#  ('involving', 707),
#  ('b', 706),
#  ('awesome', 703),
#  ('cut', 700),
#  ('sam', 699),
#  ('younger', 698),
#  ('exciting', 698),
#  ('7', 697),
#  ('books', 697),
#  ('lame', 696),
#  ('impressive', 694),
#  ('barely', 693),
#  ('showed', 693),
#  ('soldiers', 692),
#  ('superb', 690),
#  ('charles', 688),
#  ('failed', 688),
#  ('values', 687),
#  ('thinks', 686),
#  ('jim', 684),
#  ('convincing', 683),
#  ('literally', 683),
#  ('aside', 683),
#  ('christmas', 682),
#  ('added', 681),
#  ('8', 681),
#  ('cast', 680),
#  ('thanks', 680),
#  ('90', 677),
#  ('runs', 675),
#  ('secret', 674),
#  ('audiences', 674),
#  ('ben', 673),
#  ('bought', 673),
#  ('mary', 666),
#  ('personally', 665),
#  ('cinematic', 664),
#  ('sitting', 660),
#  ('amusing', 660),
#  ('honestly', 660),
#  ('miss', 660),
#  ('remains', 660),
#  ('considered', 659),
#  ('steve', 657),
#  ('issues', 655),
#  ('hit', 654),
#  ('sweet', 652),
#  ('surprisingly', 651),
#  ('frank', 650),
#  ('utterly', 650),
#  ('mad', 649),
#  ('twists', 646),
#  ('beautifully', 645),
#  ('jones', 645),
#  ('nowhere', 645),
#  ('likely', 643),
#  ('normal', 642),
#  ('starring', 642),
#  ('van', 641),
#  ('enjoy', 640),
#  ('available', 639),
#  ('present', 637),
#  ('terms', 637),
#  ('lovely', 637),
#  ('honest', 635),
#  ('generally', 635),
#  ('try', 634),
#  ('glad', 632),
#  ('managed', 631),
#  ('natural', 630),
#  ('pictures', 630),
#  ('15', 630),
#  ('charlie', 627),
#  ('100', 625),
#  ('bizarre', 623),
#  ('chris', 622),
#  ('emotions', 620),
#  ('loves', 620),
#  ('outstanding', 616),
#  ('south', 615),
#  ('london', 615),
#  ('tony', 614),
#  ('run', 613),
#  ('sick', 613),
#  ('presented', 613),
#  ('laughable', 613),
#  ('painful', 613),
#  ('fair', 612),
#  ('places', 611),
#  ('central', 611),
#  ('viewing', 611),
#  ('naked', 611),
#  ('disturbing', 610),
#  ('wonder', 609),
#  ('historical', 608),
#  ('rare', 607),
#  ('fighting', 607),
#  ('names', 605),
#  ('equally', 605),
#  ('animated', 605),
#  ('intended', 605),
#  ('tough', 603),
#  ('feelings', 603),
#  ('unbelievable', 603),
#  ('costumes', 602),
#  ('changes', 602),
#  ('bruce', 602),
#  ('intelligent', 601),
#  ('disappointing', 601),
#  ('indian', 600),
#  ('yeah', 600),
#  ('constantly', 599),
#  ('cold', 599),
#  ('violent', 598),
#  ('thus', 598),
#  ('puts', 597),
#  ('hate', 597),
#  ('besides', 596),
#  ('harry', 596),
#  ('ed', 595),
#  ('smith', 594),
#  ('9', 593),
#  ('details', 593),
#  ('pieces', 593),
#  ('expectations', 592),
#  ('subtle', 592),
#  ('comedies', 592),
#  ('na', 591),
#  ('stands', 591),
#  ('surely', 590),
#  ('slowly', 589),
#  ('potential', 589),
#  ('acts', 588),
#  ('contains', 586),
#  ('fully', 585),
#  ('la', 585),
#  ('knowing', 584),
#  ('pure', 582),
#  ('paris', 581),
#  ('confused', 580),
#  ('themes', 580),
#  ('military', 579),
#  ('horror', 579),
#  ('suppose', 579),
#  ('touching', 578),
#  ('tired', 578),
#  ('makers', 578),
#  ('critics', 578),
#  ('complex', 577),
#  ('ahead', 575),
#  ('6', 575),
#  ('minor', 573),
#  ('laughed', 573),
#  ('mainly', 573),
#  ('aspects', 572),
#  ('mysterious', 569),
#  ('west', 566),
#  ('green', 566),
#  ('finding', 566),
#  ('please', 566),
#  ('zombies', 562),
#  ('screen', 561),
#  ('students', 561),
#  ('sound', 560),
#  ('wild', 559),
#  ('light', 558),
#  ('thrown', 557),
#  ('giant', 556),
#  ('cute', 555),
#  ('hitchcock', 555),
#  ('play', 553),
#  ('smart', 552),
#  ('mark', 552),
#  ('christopher', 549),
#  ('innocent', 548),
#  ('folks', 548),
#  ('martin', 548),
#  ('stewart', 547),
#  ('billy', 547),
#  ('hoping', 547),
#  ('adds', 546),
#  ('stunning', 546),
#  ('start', 546),
#  ('ii', 545),
#  ('falling', 544),
#  ('walking', 544),
#  ('dies', 544),
#  ('holes', 544),
#  ('seemingly', 543),
#  ('lacks', 543),
#  ('70', 541),
#  ('flicks', 541),
#  ('happening', 541),
#  ('plain', 541),
#  ('silent', 540),
#  ('ray', 540),
#  ('sent', 540),
#  ('lived', 538),
#  ('drugs', 538),
#  ('sexy', 537),
#  ('supposedly', 537),
#  ('fresh', 536),
#  ('terrific', 536),
#  ('fake', 536),
#  ('faces', 535),
#  ('mr', 534),
#  ('50', 534),
#  ('developed', 533),
#  ('kelly', 532),
#  ('blue', 532),
#  ('beginning', 531),
#  ('russian', 531),
#  ('fell', 529),
#  ('million', 529),
#  ('funniest', 529),
#  ('reminded', 529),
#  ('merely', 528),
#  ('girl', 526),
#  ('relationships', 525),
#  ('led', 524),
#  ('likable', 523),
#  ('public', 523),
#  ('provides', 521),
#  ('twice', 520),
#  ('delivers', 519),
#  ('confusing', 519),
#  ('standards', 519),
#  ('rock', 518),
#  ('helps', 518),
#  ('intense', 518),
#  ('victims', 517),
#  ('appeared', 517),
#  ('murders', 517),
#  ('putting', 516),
#  ('woods', 516),
#  ('rented', 516),
#  ('impressed', 515),
#  ('day', 514),
#  ('fascinating', 514),
#  ('lies', 514),
#  ('attractive', 513),
#  ('six', 513),
#  ('creative', 513),
#  ('gorgeous', 512),
#  ('understand', 512),
#  ('adults', 512),
#  ('rated', 512),
#  ('narrative', 512),
#  ('jason', 509),
#  ('followed', 508),
#  ('born', 507),
#  ('allowed', 506),
#  ('flaws', 506),
#  ('heavy', 506),
#  ('kevin', 505),
#  ('games', 504),
#  ('nasty', 504),
#  ('story', 503),
#  ('animals', 502),
#  ('paid', 501),
#  ('becoming', 500),
#  ('ugly', 500),
#  ('onto', 499),
#  ('gay', 498),
#  ('feeling', 496),
#  ('tragic', 496),
#  ('seconds', 496),
#  ('cops', 495),
#  ('lets', 494),
#  ('christian', 493),
#  ('seven', 493),
#  ('rarely', 492),
#  ('americans', 492),
#  ('actions', 491),
#  ('boy', 490),
#  ('brief', 490),
#  ('offers', 489),
#  ('returns', 489),
#  ('angry', 489),
#  ('dreams', 488),
#  ('picked', 488),
#  ('ryan', 488),
#  ('moved', 486),
#  ('charming', 485),
#  ('forever', 485),
#  ('willing', 485),
#  ('moral', 485),
#  ('states', 483),
#  ('henry', 482),
#  ('agree', 482),
#  ('inspired', 481),
#  ('editing', 480),
#  ('negative', 478),
#  ('proves', 478),
#  ('johnny', 478),
#  ('physical', 477),
#  ('wondering', 476),
#  ('artistic', 476),
#  ('thomas', 474),
#  ('jerry', 474),
#  ('jackson', 474),
#  ('bits', 473),
#  ('began', 473),
#  ('ready', 472),
#  ('tim', 471),
#  ('earth', 471),
#  ('shooting', 470),
#  ('holds', 470),
#  ('batman', 470),
#  ('clever', 468),
#  ('turning', 467),
#  ('asked', 467),
#  ('helped', 467),
#  ('actresses', 466),
#  ('realized', 466),
#  ('necessary', 466),
#  ('independent', 464),
#  ('thoroughly', 464),
#  ('wearing', 463),
#  ('williams', 463),
#  ('thats', 462),
#  ('limited', 459),
#  ('anywhere', 459),
#  ('held', 459),
#  ('wars', 459),
#  ('therefore', 458),
#  ('watchable', 458),
#  ('sucks', 458),
#  ('afraid', 457),
#  ('asks', 457),
#  ('stuck', 457),
#  ('reminds', 457),
#  ('male', 456),
#  ('dying', 456),
#  ('life', 455),
#  ('forgotten', 455),
#  ('shakespeare', 455),
#  ('arts', 455),
#  ('introduced', 454),
#  ('let', 454),
#  ('anymore', 452),
#  ('religious', 452),
#  ('clothes', 451),
#  ('wooden', 451),
#  ('creepy', 451),
#  ('extra', 451),
#  ('bond', 451),
#  ('wanting', 449),
#  ('chinese', 449),
#  ('cgi', 449),
#  ('unusual', 449),
#  ('brian', 448),
#  ('flying', 448),
#  ('dangerous', 448),
#  ('wow', 448),
#  ('directing', 448),
#  ('martial', 448),
#  ('ford', 447),
#  ('end', 447),
#  ('dancing', 444),
#  ('includes', 443),
#  ('alien', 443),
#  ('heroes', 443),
#  ('serial', 441),
#  ('calls', 440),
#  ('remarkable', 439),
#  ('memories', 439),
#  ('allen', 438),
#  ('nicely', 438),
#  ('stephen', 437),
#  ('scared', 436),
#  ('fox', 436),
#  ('responsible', 436),
#  ('tears', 435),
#  ('mike', 435),
#  ('numbers', 434),
#  ('surprising', 433),
#  ('professional', 433),
#  ('super', 432),
#  ('park', 432),
#  ('powers', 431),
#  ('unnecessary', 430),
#  ('quick', 430),
#  ('sat', 429),
#  ('death', 429),
#  ...]
